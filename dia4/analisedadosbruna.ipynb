# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/dados.csv')

# %% [markdown]
# #printando os dados na tela

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# #vendo quantas linhas e quantas colunas tem

# %%
df.shape
# Out:
# (1000, 8)

# %% [markdown]
# #vendo quantos nulls tem

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# #vendo os tipos de variaveis presentes na tabela

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# #vendo os dados nulos

# %%
df.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %% [markdown]
# #usando describe para pegar minimo, maximo e media

# %%
df.describe()
# math: min = 0, max = 100, mean = 66
# reading: min = 17, max = 100, mean = 69
# writing: min = 10, max = 100, mean = 68
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# #agrupando o banco a partir de raça e etnia e plotando grafico com as notas de matematica e a media

# %%
df2 = df.groupby('race/ethnicity')[['math score']].mean()

# %% [markdown]
# #printando o agrupamento

# %%
df2
# Out:
#                 math score
# race/ethnicity
# group A          61.629213
# group B          63.452632
# group C          64.463950
# group D          67.362595
# group E          73.821429

# %% [markdown]
# #plotando um grafico de barras para demonstrar a media em matematica de cada raça/etnia, demonstrando que o grupo D e o grupo E tiveram notas maiores em matematica

# %%
df2.plot(kind = 'bar', figsize = (4,2), color = 'purple')
# Out:
# <Axes: xlabel='race/ethnicity'>

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# #agrupando o nivel de escolaridade e plotando com a media das notas em escrita

# %%
df3 = df.groupby('parental level of education')[['writing score']].mean()

# %% [markdown]
# #printando

# %%
df3
# Out:
#                              writing score
# parental level of education
# associate's degree               69.896396
# bachelor's degree                73.381356
# high school                      62.448980
# master's degree                  75.677966
# some college                     68.840708
# some high school                 64.888268

# %% [markdown]
# #plotando grafico em linha que mostra que os niveis de escolaridade bachelor´s degree e master´s degree obtiveram notas maiores

# %%
df3.plot(kind = 'line', figsize = (10,3), color = 'red', marker = 'o')
# Out:
# <Axes: xlabel='parental level of education'>

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# #agrupando test preparation couse e plotandp grafico sobre a media das notas em leitura

# %%
df4 = df.groupby('test preparation course')[['reading score']].mean()

# %% [markdown]
# #printando

# %%
df4
# Out:
#                          reading score
# test preparation course
# completed                    73.893855
# none                         66.534268

# %% [markdown]
# #plotando dois graficos, um de torta e um de barras que demonstram que quem tem cursos preparatorios tem notas maiores

# %%
df4.plot(kind = 'pie', subplots = True)
df4.plot(kind = 'bar', figsize = (4,2), color = 'green')
# Out:
# <Axes: xlabel='test preparation course'>
